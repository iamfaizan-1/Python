# %%
print("Hello world")

myTuple = [1,2,3,4,5]

print(myTuple)
# Out:
# Hello world
# [1, 2, 3, 4, 5]

# %%
# checking data type

type(True)
type("My name is faizan")
type('m')
# Out:
# str

# %%
# changing cases

"Hello world".upper()
"Hello world".lower()
"Hello world".title()
# Out:
# 'Hello World'

# %%
# count function

name = "Muhammad Faizan"
print(name.count('a'))
# Out:
# 4

# %% [markdown]
# # Title

# %%
#replace function
name = "faizan"
print(name.replace('a','i'))
# Out:
# fiizin

# %%
f'{name}'
# Out:
# 'faizan'
