# %%
import os

os.getcwd()
# Out:
# ['first.ipynb']

# %%
os.listdir()
# Out:
# ['first.ipynb', 'New folder']

# %%
os.makedirs("New folder")

# %%
print("Hello world")

myTuple = [1,2,3,4,5]

print(myTuple)
# Out:
# Hello world
# [1, 2, 3, 4, 5]

# %%
# checking data type

type(True)
type("My name is faizan")
type('m')
# Out:
# str

# %%
# changing cases

"Hello world".upper()
"Hello world".lower()
"Hello world".title()
# Out:
# 'Hello World'

# %%
# count function

name = "Muhammad Faizan"
print(name.count('a'))
# Out:
# 4

# %% [markdown]
# # Title

# %%
#replace function
name = "faizan"
print(name.replace('a','i'))
# Out:
# fiizin

# %%
f'{name}'
# Out:
# 'faizan'

# %% [markdown]
# # 1. Lists

# %%
# Lists

countries = ['Pakistan','Germany','Italy']
countries
# Out:
# ['Pakistan', 'Germany', 'Italy']

# %%
countries[-1]
# Out:
# 'Italy'

# %%
# slicing

countries[0:2]
# Out:
# ['Pakistan', 'Germany']

# %%
countries[0:3]
# Out:
# ['Pakistan', 'Germany', 'Italy']

# %%
# it runs from 0 index to end

countries[0:]
# Out:
# ['Pakistan', 'Germany', 'Italy']

# %%
# the starting index is 1 , so it reads from 1 to end

countries[1:]
# Out:
# ['Germany', 'Italy']

# %%
# only added the last element, so it is starting from 0 index to 2 index
countries[:2]
# Out:
# ['Pakistan', 'Germany']

# %% [markdown]
# # Adding items to list

# %%
countries
# Out:
# ['Pakistan', 'Germany', 'Italy']

# %%
countries.append('Canada')

# %%
countries
# Out:
# ['Pakistan', 'Germany', 'Italy', 'Canada']
