# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. line plot

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
sales = [20, 35, 25, 40, 50]

# %%
plt.plot(days, sales)
plt.show()

# %% [markdown]
# ## 2.bar chart

# %%
plt.bar(days, sales)
plt.show()
