# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %% [markdown]
# # 1. Selecting a column

# %% [markdown]
# ## 1.1 Syntax 1

# %%
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
type(df['gender'])
# Out:
# pandas.Series

# %%
df['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: str

# %% [markdown]
# ## 1.2 Syntax 2

# %%
# select using .

# this is not the best method because if the column name has space , so with this method we cannot access it.

df.gender

# but we can't access math score column because it has gap

# %% [markdown]
# # 2. Selecting two or more columns

# %%
df[['gender','math score']]

# %%
# checkin type of selected columns

type(df[['gender','math score']])
# Out:
# pandas.DataFrame
